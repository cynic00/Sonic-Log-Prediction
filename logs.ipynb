# %%
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
import numpy as np
from sklearn.metrics import r2_score,mean_squared_error
import seaborn as sns

# %%
#Data pre-processing
df=pd.read_csv('/content/book.csv')
print(df.head())
#print(df.tail())
df = df[df.GR != -999.25]
df = df[df.Neutron_porosity != -999.25]
df = df[df.PEF != -999.25]
df = df[df.Potasium != -999.25]
df = df[df.RESD != -999.25]
df = df[df.RESM != -999.25]
df = df[df.RESS != -999.25]
df = df[df.Density != -999.25]
df = df[df.THOR != -999.25]
df = df[df.URAN != -999.25]
df = df[df.DTC != -999.25]
df = df[df.DTS != -999.25]
df = df.reset_index(drop=True)
# Out:
#           GR  Neutron_porosity       PEF  ...        URAN        DTC         DTS
# 0  34.858700          0.219650  8.830400  ... -999.250000  77.539398  142.440399
# 1  36.819408          0.216217  8.980547  ... -999.250000  74.924561  140.393494
# 2  36.806541          0.211112  9.107201  ...    0.603836  73.036903  138.190506
# 3  34.596245          0.218566  9.098256  ...    0.596240  72.451294  136.373795
# 4  32.187355          0.227669  9.039493  ...    0.576144  72.868149  134.836502
#
# [5 rows x 12 columns]

# %%
df=df.reset_index()
plt.rcParams.update({'font.size': 25})

fig=plt.subplots(figsize=(25,15))
ax1=plt.subplot2grid((3,4), (0,0), rowspan=3,colspan=1)

#GR
ax1.plot('GR','index', data=df)
#ax1.set_title('GR')
plt.xlabel('Gamma Ray (gAPI)')
plt.ylabel('Index')
ax1.grid()



#NPHI
fig=plt.subplots(figsize=(25,15))
ax1=plt.subplot2grid((3,4), (0,0), rowspan=3,colspan=1)
# np
ax1.plot('Neutron_porosity','index', data=df)
#ax1.set_title('Neutron porosity')
plt.xlabel('Neutron porosity (m3/m3)')
plt.ylabel('Index')
ax1.grid()



#PEF
fig=plt.subplots(figsize=(25,15))
ax1=plt.subplot2grid((3,4), (0,0), rowspan=3,colspan=1)
# np
ax1.plot('PEF','index', data=df)
#ax1.set_title('Neutron porosity')
plt.xlabel('PEF (b/e) ')
plt.ylabel('Index')
ax1.grid()


#POTA
fig=plt.subplots(figsize=(25,15))
ax1=plt.subplot2grid((3,4), (0,0), rowspan=3,colspan=1)
# np
ax1.plot('Potasium','index', data=df)
#ax1.set_title('Neutron porosity')
plt.xlabel('Potassium (%)')
plt.ylabel('Index')
ax1.grid()


#RESD
fig=plt.subplots(figsize=(25,15))
ax1=plt.subplot2grid((3,4), (0,0), rowspan=3,colspan=1)
# np
ax1.plot('RESD','index', data=df)
#ax1.set_title('Neutron porosity')
plt.xlabel('RESD (ohm.m)')
plt.ylabel('Index')
ax1.grid()

#RESM
fig=plt.subplots(figsize=(25,15))
ax1=plt.subplot2grid((3,4), (0,0), rowspan=3,colspan=1)
# np
ax1.plot('RESM','index', data=df)
#ax1.set_title('Neutron porosity')
plt.xlabel('RESM (ohm.m)')
plt.ylabel('Index')
ax1.grid()

#RESS
fig=plt.subplots(figsize=(25,15))
ax1=plt.subplot2grid((3,4), (0,0), rowspan=3,colspan=1)
# np
ax1.plot('RESS','index', data=df)
#ax1.set_title('Neutron porosity')
plt.xlabel('RESS (ohm.m)')
plt.ylabel('Index')
ax1.grid()



#Density
fig=plt.subplots(figsize=(25,15))
ax1=plt.subplot2grid((3,4), (0,0), rowspan=3,colspan=1)
# np
ax1.plot('Density','index', data=df)
#ax1.set_title('Neutron porosity')
plt.xlabel('Density (g/cc)')
plt.ylabel('Index')
ax1.grid()


#THOR
fig=plt.subplots(figsize=(25,15))
ax1=plt.subplot2grid((3,4), (0,0), rowspan=3,colspan=1)
# np
ax1.plot('THOR','index', data=df)
#ax1.set_title('Neutron porosity')
plt.xlabel('Thorium (ppm)')
plt.ylabel('Index')
ax1.grid()


#URAN
fig=plt.subplots(figsize=(25,15))
ax1=plt.subplot2grid((3,4), (0,0), rowspan=3,colspan=1)
# np
ax1.plot('URAN','index', data=df)
#ax1.set_title('Neutron porosity')
plt.xlabel('Uranium (ppm)')
plt.ylabel('Index')
ax1.grid()

#DTC
fig=plt.subplots(figsize=(25,15))
ax1=plt.subplot2grid((3,4), (0,0), rowspan=3,colspan=1)
# np
ax1.plot('DTC','index', data=df)
#ax1.set_title('Neutron porosity')
plt.xlabel('DTC (μs/ft)')
plt.ylabel('Index')
ax1.grid()


#DTS
fig=plt.subplots(figsize=(25,15))
ax1=plt.subplot2grid((3,4), (0,0), rowspan=3,colspan=1)
# np
ax1.plot('DTS','index', data=df)
#ax1.set_title('Neutron porosity')
plt.xlabel('DTS (μs/ft)')
plt.ylabel('Index')
ax1.grid()
