# %%
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
import numpy as np
from sklearn.metrics import r2_score,mean_squared_error
import seaborn as sns

# %%
#Data pre-processing
df=pd.read_csv('book.csv')
print(df.head())
#print(df.tail())
df = df[df.GR != -999.25]
df = df[df.Neutron_porosity != -999.25]
df = df[df.PEF != -999.25]
df = df[df.Potasium != -999.25]
df = df[df.RESD != -999.25]
df = df[df.RESM != -999.25]
df = df[df.RESS != -999.25]
df = df[df.Density != -999.25]
df = df[df.THOR != -999.25]
df = df[df.URAN != -999.25]
df = df[df.DTC != -999.25]
df = df[df.DTS != -999.25]
df = df.reset_index(drop=True)
# Out:
#           GR  Neutron_porosity       PEF    Potasium      RESD      RESM  \
# 0  34.858700          0.219650  8.830400 -999.250000  2.661294  2.592666
# 1  36.819408          0.216217  8.980547 -999.250000  2.346075  2.305736
# 2  36.806541          0.211112  9.107201    0.762118  2.080422  2.128788
# 3  34.596245          0.218566  9.098256    0.675480  2.070979  2.146933
# 4  32.187355          0.227669  9.039493    0.632915  2.463068  2.513778
#
#        RESS   Density        THOR        URAN        DTC         DTS
# 0  2.523428  2.704046 -999.250000 -999.250000  77.539398  142.440399
# 1  2.194569  2.687440 -999.250000 -999.250000  74.924561  140.393494
# 2  2.144159  2.677008    2.715095    0.603836  73.036903  138.190506
# 3  2.216718  2.674053    2.486746    0.596240  72.451294  136.373795
# 4  2.616725  2.676515    2.589289    0.576144  72.868149  134.836502

# %%
#Define the dependent variable that needs to be predicted (DTC)
Y = df["DTS"]
#Define the independent variables.
X = df.drop(labels = ["DTS"], axis=1) 
x = X.to_numpy()
y = Y.to_numpy()
y = np.reshape(y,(1, y.size))
y=np.transpose(y, axes=None)
#Scale
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(x)
x = scaler.transform(x)
scaler.fit(y)
y = scaler.transform(y)

# %%
#Split data into train and test to verify accuracy after fitting the model. 
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)

# %%
#ann
model = Sequential()         
model.add(Dense(128, input_dim=11, activation='relu')) 
model.add(Dropout(0.2))
model.add(Dense(1))   
model.compile(loss='mean_squared_error',
              optimizer='adam',)             #also try other optimisers


#model.compile(loss='mean_squared_error', optimizer='adam')
print(model.summary())

#Fit with no early stopping or other callbacks
history = model.fit(X_train, y_train ,verbose=1, epochs=500, 
                    validation_data=(X_test, y_test))

# Predict
y_pred_ann = model.predict(X_test)    
print("Mean sq. errror for ann =", np.mean(y_pred_ann-y_test)**2)
print(r2_score(y_test, y_pred_ann))

#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
#plt.savefig('DTS2_plots/Training and validation loss.png')
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               1536
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 1,665
# Trainable params: 1,665
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/500
# 256/256 [==============================] - 4s 10ms/step - loss: 0.0247 - val_loss: 0.0020
# Epoch 2/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0036 - val_loss: 0.0017
# Epoch 3/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0026 - val_loss: 0.0019
# Epoch 4/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0024 - val_loss: 0.0017
# Epoch 5/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0025 - val_loss: 0.0015
# Epoch 6/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0022 - val_loss: 0.0015
# Epoch 7/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0022 - val_loss: 0.0015
# Epoch 8/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0022 - val_loss: 0.0014
# Epoch 9/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0020 - val_loss: 0.0014
# Epoch 10/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0020 - val_loss: 0.0014
# Epoch 11/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 12/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 13/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 14/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 15/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 16/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 17/500
# 256/256 [==============================] - 1s 3ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 18/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 19/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 20/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 21/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 22/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 23/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 24/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 25/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 26/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 27/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 28/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 29/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 30/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 31/500
# 256/256 [==============================] - 1s 3ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 32/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 33/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 34/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 35/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 36/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 37/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 38/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 39/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 40/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 41/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 42/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 43/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 44/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 45/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 46/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 47/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 48/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 49/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 50/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 51/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 52/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 53/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 54/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 55/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 56/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 57/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 58/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 59/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 60/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 61/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 62/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 63/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 64/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 65/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 66/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 67/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 68/500
# 256/256 [==============================] - 1s 3ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 69/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 70/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 71/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 72/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 73/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 74/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 75/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 76/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 77/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 78/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 79/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 80/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 81/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 82/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 83/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 84/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 85/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 86/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 87/500
# 256/256 [==============================] - 1s 3ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 88/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 89/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 90/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 91/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 92/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 93/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 94/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 95/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 96/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 97/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 98/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 99/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 100/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 101/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 102/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 103/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 104/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 105/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 106/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 107/500
# 256/256 [==============================] - 1s 3ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 108/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 109/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 110/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 111/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 112/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 113/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 114/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 115/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 116/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 117/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 118/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 119/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 120/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 121/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 122/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 123/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 124/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 125/500
# 256/256 [==============================] - 1s 3ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 126/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 127/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 128/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 129/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 130/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 131/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 132/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 133/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 134/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 135/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 136/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 137/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 138/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 139/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 140/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 141/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 142/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 143/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 144/500
# 256/256 [==============================] - 1s 3ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 145/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 146/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 147/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 148/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 149/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 150/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 151/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 152/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 153/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 154/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 155/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 156/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.00120
# Epoch 157/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 158/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 159/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 160/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 161/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 162/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 163/500
# 256/256 [==============================] - 1s 3ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 164/500
# 256/256 [==============================] - 1s 3ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 165/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 166/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 167/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 168/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 169/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 170/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 171/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 172/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 173/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 174/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 175/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 176/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 177/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 178/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 179/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 180/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 181/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 182/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 183/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 184/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 185/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 186/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 187/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 188/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 189/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 190/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 191/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 192/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 193/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 194/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 195/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 196/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 197/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 198/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 199/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 200/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 201/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 202/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 203/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 204/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 205/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 206/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 207/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 208/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 209/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 210/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 211/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 212/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 213/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 214/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 215/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 216/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 217/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 218/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 219/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 220/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 221/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 222/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 223/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 224/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 225/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 226/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 227/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 228/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 229/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 230/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 231/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 232/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 233/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 234/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 235/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 236/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 237/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 238/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 239/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 240/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 241/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 242/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 243/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 244/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 245/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 246/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 247/500
# 256/256 [==============================] - 1s 3ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 248/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 249/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 250/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 251/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 252/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 253/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 254/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 255/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 256/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 257/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 258/500
# 256/256 [==============================] - 1s 3ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 259/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 260/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 261/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 262/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 263/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 264/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 265/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 266/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 267/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 268/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 269/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 270/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 271/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 272/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 273/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 274/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 275/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 276/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 277/500
# 256/256 [==============================] - 1s 3ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 278/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 279/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 280/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 281/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 282/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 283/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 284/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 285/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 286/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 287/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 288/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 289/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 290/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 291/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 292/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 293/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 294/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 295/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 296/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 297/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 298/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 299/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 300/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 301/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 302/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 303/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 304/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 305/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 306/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 307/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 308/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 309/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 310/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 311/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 312/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 313/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 314/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 315/500
# 256/256 [==============================] - 1s 3ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 316/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 317/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 318/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 319/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 320/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 321/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 322/500
# 256/256 [==============================] - 1s 3ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 323/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.00130
# Epoch 324/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 325/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 326/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 327/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 328/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 329/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 330/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 331/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 332/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 333/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 334/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 335/500
# 256/256 [==============================] - 1s 3ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 336/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 337/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 338/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 339/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 340/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 341/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 342/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 343/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 344/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 345/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 346/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 347/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 348/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 349/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 350/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 351/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 352/500
# 256/256 [==============================] - 1s 3ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 353/500
# 256/256 [==============================] - 1s 3ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 354/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 355/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 356/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 357/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 358/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 359/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 360/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 361/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 362/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 363/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 364/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 365/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 366/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 367/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 368/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 369/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 370/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 371/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 372/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 373/500
# 256/256 [==============================] - 1s 3ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 374/500
# 256/256 [==============================] - 1s 3ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 375/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 376/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 377/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 378/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 379/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 380/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 381/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 382/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 383/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 384/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 385/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 386/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 387/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 388/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 389/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 390/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 391/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 392/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 393/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 394/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 395/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 396/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 397/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 398/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 399/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 400/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 401/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 402/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 403/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 404/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 405/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 406/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 407/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 408/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 409/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 410/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 411/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 412/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 413/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 414/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 415/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 416/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 417/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 418/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 419/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 420/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 421/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 422/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 423/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 424/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 425/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 426/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 427/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 428/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 429/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 430/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 431/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 432/500
# 256/256 [==============================] - 1s 3ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 433/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 434/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 435/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 436/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 437/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 438/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 439/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 440/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 441/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 442/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 443/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 444/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 445/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 446/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 447/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 448/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 449/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 450/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 451/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 452/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 453/500
# 256/256 [==============================] - 1s 3ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 454/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 455/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 456/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 457/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 458/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 459/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 460/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 461/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 462/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 463/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 464/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 465/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 466/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 467/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 468/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 469/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 470/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 471/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 472/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 473/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 474/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 475/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 476/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 477/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 478/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 479/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 480/500
# 256/256 [==============================] - 1s 3ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 481/500
# 256/256 [==============================] - 1s 3ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 482/500
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 483/500
# 256/256 [==============================] - 1s 3ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 484/500
# 256/256 [==============================] - 1s 3ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 485/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 486/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 487/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 488/500
# 256/256 [==============================] - 1s 3ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 489/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 490/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 491/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 492/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 493/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 494/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 495/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 496/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 497/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 498/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 499/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 500/500
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Mean sq. errror for ann = 3.056159770473148e-06
# 0.9609011780908852

# %%
#Decision-Tree-Regression
from sklearn.tree import DecisionTreeRegressor
DecisionTreeRegModel = DecisionTreeRegressor(max_depth=10,
                           min_samples_split=2,
                           max_leaf_nodes=200,min_samples_leaf=6)
DecisionTreeRegModel.fit(X_train,y_train)
y_pred_Decision_Tree_test = DecisionTreeRegModel.predict(X_test)
y_pred_Decision_Tree_train = DecisionTreeRegModel.predict(X_train)
print("Mean sq. errror for Decision-Tree-Regression  =", np.mean(y_pred_Decision_Tree_test-y_test)**2)
print(r2_score(y_test, y_pred_Decision_Tree_test))
print(r2_score(y_train, y_pred_Decision_Tree_train))
# Out:
# Mean sq. errror for Decision-Tree-Regression  = 1.2145963864929717e-07
# 0.9488362728874495
# 0.9690856760972484

# %%
from sklearn.model_selection import KFold,GridSearchCV, cross_val_score, cross_val_predict
param_grid = {"criterion": ["mse", "mae"],
              "min_samples_split": [2,3],
              "max_depth": [10, 11, 12],
              "min_samples_leaf": [4, 6, 8],
              "max_leaf_nodes": [100, 150, 200],
              }
kf = KFold(n_splits=2)
## Comment in order to publish in kaggle.

grid_cv_dtm = GridSearchCV(DecisionTreeRegModel, param_grid, cv=kf)

grid_cv_dtm.fit(X_train,y_train)

print("R-Squared::{}".format(grid_cv_dtm.best_score_))
print("Best Hyperparameters::\n{}".format(grid_cv_dtm.best_params_))
# Out:
# R-Squared::0.9438817875604593
# Best Hyperparameters::
# {'criterion': 'mse', 'max_depth': 10, 'max_leaf_nodes': 200, 'min_samples_leaf': 6, 'min_samples_split': 3}

# %%
df1 = pd.DataFrame(data=grid_cv_dtm.cv_results_)
fig,ax = plt.subplots()
sns.pointplot(data=df1[['mean_test_score',
                           'param_max_leaf_nodes',
                           'param_max_depth']],
             y='mean_test_score',x='param_max_depth',
             hue='param_max_leaf_nodes',ax=ax)
ax.set(title="Effect of Depth and Leaf Nodes on Model Performance")
# Out:
# [Text(0.5, 1.0, 'Effect of Depth and Leaf Nodes on Model Performance')]

# %%
fig,ax = plt.subplots()
sns.pointplot(data=df1[['mean_test_score',
                           'param_max_leaf_nodes',
                           'param_max_depth']],
             y='mean_test_score',x='param_max_depth',
             hue='param_max_leaf_nodes',ax=ax)
ax.set(title="Effect of Depth and Leaf Nodes on Model Performance")
# Out:
# [Text(0.5, 1.0, 'Effect of Depth and Leaf Nodes on Model Performance')]

# %%
fig,ax = plt.subplots()
sns.pointplot(data=df1[['mean_test_score',
                           'param_max_leaf_nodes',
                           'param_max_depth']],
             y='mean_test_score',x='param_max_depth',
             hue='param_max_leaf_nodes',ax=ax)
ax.set(title="Effect of Depth and Leaf Nodes on Model Performance")
# Out:
# [Text(0.5, 1.0, 'Effect of Depth and Leaf Nodes on Model Performance')]

# %%
#random forest
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 400,max_features='sqrt', random_state = 42,max_depth=40,min_samples_split=3,
                                  min_samples_leaf=1,bootstrap=False)
regressor.fit(X_train,y_train)
y_pred_randomforest_test = regressor.predict(X_test)
y_pred_randomforest_train = regressor.predict(X_train)
print("Mean sq. errror for randomforest  =", np.mean(y_pred_randomforest_test-y_test)**2)
print(r2_score(y_test, y_pred_randomforest_test))
print(r2_score(y_train, y_pred_randomforest_train))
# Out:
# <ipython-input-11-d5a57587a744>:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regressor.fit(X_train,y_train)
# Mean sq. errror for randomforest  = 1.0627590470968432e-07
# 0.9713674210221319
# 0.9999473582269579

# %%
rf = RandomForestRegressor(n_estimators=1)
train=[]
test=[]
itera=[]
r2=[]
for iter in range(50):
    rf.fit(X_train, y_train)
    y_train_predicted = rf.predict(X_train)
    y_test_predicted = rf.predict(X_test)
    mse_train = mean_squared_error(y_train, y_train_predicted)
    mse_test = mean_squared_error(y_test, y_test_predicted)
    rf.n_estimators += 1
    R=r2_score(y_test,y_test_predicted)
    train.append(mse_train)
    test.append(mse_test)
    itera.append(iter)
    r2.append(R)

plt.plot(itera, train, 'y', label='Training loss')
plt.plot(itera, test, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('number of tree')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.plot(itera, r2, 'y', label='Training loss')
# Out:
# <ipython-input-12-c1123912c475>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-12-c1123912c475>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-12-c1123912c475>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-12-c1123912c475>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-12-c1123912c475>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-12-c1123912c475>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-12-c1123912c475>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-12-c1123912c475>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-12-c1123912c475>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-12-c1123912c475>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-12-c1123912c475>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-12-c1123912c475>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-12-c1123912c475>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-12-c1123912c475>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-12-c1123912c475>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-12-c1123912c475>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-12-c1123912c475>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-12-c1123912c475>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-12-c1123912c475>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-12-c1123912c475>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-12-c1123912c475>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-12-c1123912c475>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-12-c1123912c475>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-12-c1123912c475>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-12-c1123912c475>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-12-c1123912c475>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-12-c1123912c475>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-12-c1123912c475>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-12-c1123912c475>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-12-c1123912c475>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-12-c1123912c475>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-12-c1123912c475>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-12-c1123912c475>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-12-c1123912c475>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-12-c1123912c475>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-12-c1123912c475>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-12-c1123912c475>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-12-c1123912c475>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-12-c1123912c475>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-12-c1123912c475>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-12-c1123912c475>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-12-c1123912c475>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-12-c1123912c475>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-12-c1123912c475>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-12-c1123912c475>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-12-c1123912c475>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-12-c1123912c475>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-12-c1123912c475>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-12-c1123912c475>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-12-c1123912c475>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)

# %%
param_grid = {
    'bootstrap': [True, False],
    'max_depth': [40, 60, 80],
    'max_features': ['auto','sqrt'],
    'min_samples_leaf': [1, 2],
    'min_samples_split': [1, 3, 5],
    'n_estimators': [200, 300, 400]
}
# Instantiate the grid search model
grid_search = GridSearchCV(regressor, param_grid = param_grid, 
                          cv = 3, n_jobs = -1, verbose = 2)
grid_search.fit(X_train,y_train)
print("R-Squared::{}".format(grid_search.best_score_))
print("Best Hyperparameters::\n{}".format(grid_search.best_params_))
# Out:
# Fitting 3 folds for each of 216 candidates, totalling 648 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=-1)]: Done 349 tasks      | elapsed: 17.0min
# [Parallel(n_jobs=-1)]: Done 632 tasks      | elapsed: 33.2min
# [Parallel(n_jobs=-1)]: Done 648 out of 648 | elapsed: 33.8min finished
# D:\anacondahiss\lib\site-packages\sklearn\model_selection\_search.py:765: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)
# R-Squared::0.9693230284959412
# Best Hyperparameters::
# {'bootstrap': False, 'max_depth': 40, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 400}

# %%
#SVR
from sklearn.svm import SVR
regressor_svm=SVR(kernel='rbf')
regressor_svm.fit(X_train,y_train)
y_pred_svm_test=regressor_svm.predict(X_test)
y_pred_svm_train=regressor_svm.predict(X_train)
print("Mean sq. errror for SVM_rbf  =", np.mean(y_pred_svm_test-y_test)**2)
print(r2_score(y_test, y_pred_svm_test))
print(r2_score(y_train, y_pred_svm_train))
# Out:
# D:\anacondahiss\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# Mean sq. errror for SVM_rbf  = 7.358703190676728e-05
# 0.9397337162578808
# 0.9412276937495926

# %%
import xgboost as xg
# Instantiation 
xgb_r = xg.XGBRegressor(objective ='reg:squarederror',colsample_bytree=0.9,learning_rate=0.03,max_depth=18,
                        min_child_weight=3,subsample=0.4,
                  n_estimators =500) 


xgb_r.fit(X_train, y_train,verbose=True) 
  
# Predict the model 
pred_test = xgb_r.predict(X_test) 
pred_train = xgb_r.predict(X_train) 
print("Mean sq. errror for XGboost  =", np.mean(pred_test-y_test)**2)
print(r2_score(y_test, pred_test))
print(r2_score(y_train, pred_train))
# Out:
# Mean sq. errror for XGboost  = 1.8397364768660823e-08
# 0.9749421564491209
# 0.9995943756279569

# %%
param_tuning = {
        'learning_rate': [0.03,0.1],
        'max_depth': [6,12,18],
        #'min_child_weight': [1, 3, 5],
        'subsample': [0.3, 0.4, 0.7],
        'colsample_bytree': [0.7,0.8,0.9],
        'n_estimators' : [300, 400, 500],
        'objective': ['reg:squarederror']
    }

gsearch = GridSearchCV(estimator = xgb_r,
                           param_grid = param_tuning,                        
                           #scoring = 'neg_mean_absolute_error', #MAE
                           #scoring = 'neg_mean_squared_error',  #MSE
                           cv = 3,
                           n_jobs = -1,
                           verbose = 1)
gsearch.fit(X_train,y_train)
print("R-Squared::{}".format(gsearch.best_score_))
print(gsearch.best_params_)
# Out:
# Fitting 3 folds for each of 162 candidates, totalling 486 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   36.3s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  5.1min
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed: 13.0min
# [Parallel(n_jobs=-1)]: Done 486 out of 486 | elapsed: 15.0min finished
# R-Squared::0.9707957945783009
# {'colsample_bytree': 0.9, 'learning_rate': 0.03, 'max_depth': 18, 'n_estimators': 500, 'objective': 'reg:squarederror', 'subsample': 0.4}

# %%
plt.title('ANN',fontsize=15)
print("Mean sq. errror for ANN  =", np.mean(y_pred_ann-y_test)**2)
print(r2_score(y_test, y_pred_ann))
y_testa=y_test.flatten()
y_pred_anna=y_pred_ann.flatten()
plt.scatter(y_test,y_pred_ann)
plt.xlabel('Actual values')
plt.ylabel('Predicted values')
plt.plot(np.unique(y_testa), np.poly1d(np.polyfit(y_testa, y_pred_anna, 1))(np.unique(y_testa)),c='r',linewidth = '2')
plt.text(0.1, 0.8, 'R\u00b2 = %0.2f' % r2_score(y_testa, y_pred_anna))
plt.show()
#plt.savefig('DTS1_plots/ann.png')



plt.title('Decision Tree Regression',fontsize=15)
print("Mean sq. errror for Decision-Tree-Regression  =", np.mean(y_pred_Decision_Tree_test-y_test)**2)
print(r2_score(y_test, y_pred_Decision_Tree_test))
y_testa=y_test.flatten()
y_pred_Decision_Treea=y_pred_Decision_Tree_test.flatten()
plt.scatter(y_test,y_pred_Decision_Tree_test)
plt.xlabel('Actual values')
plt.ylabel('Predicted values')

plt.plot(np.unique(y_testa), np.poly1d(np.polyfit(y_testa, y_pred_Decision_Treea, 1))(np.unique(y_testa)),c='r',linewidth = '2')

plt.text(0.1, 0.8, 'R\u00b2 = %0.2f' % r2_score(y_testa, y_pred_Decision_Treea))
plt.show()
#plt.savefig('DTS1_plots/Decision Tree Regression.png')



plt.title('Random Forest Regression',fontsize=15)
print("Mean sq. errror for randomforest  =", np.mean(y_pred_randomforest_test-y_test)**2)
print(r2_score(y_test, y_pred_randomforest_test))
y_testa=y_test.flatten()
y_pred_randomforesta=y_pred_randomforest_test.flatten()
plt.scatter(y_test,y_pred_randomforest_test)
plt.xlabel('Actual values')
plt.ylabel('Predicted values')

plt.plot(np.unique(y_testa), np.poly1d(np.polyfit(y_testa, y_pred_randomforesta, 1))(np.unique(y_testa)),c='r',linewidth = '2')

plt.text(0.1, 0.8, 'R\u00b2 = %0.2f' % r2_score(y_testa, y_pred_randomforesta))
plt.show()
#plt.savefig('DTS1_plots/Random Forest.png')



plt.title('SVM Regression',fontsize=15)
print("Mean sq. errror for SVM_rbf  =", np.mean(y_pred_svm_test-y_test)**2)
print(r2_score(y_test, y_pred_svm_test))
y_testa=y_test.flatten()
y_pred_svma=y_pred_svm_test.flatten()
plt.scatter(y_test,y_pred_svm_test)
plt.xlabel('Actual values')
plt.ylabel('Predicted values')

plt.plot(np.unique(y_testa), np.poly1d(np.polyfit(y_testa, y_pred_svma, 1))(np.unique(y_testa)),c='r',linewidth = '2')

plt.text(0.1, 0.8, 'R\u00b2 = %0.2f' % r2_score(y_testa, y_pred_svma))
plt.show()
#plt.savefig('DTS1_plots/SVM.png')


plt.title('XGboost Regression',fontsize=15)
print("Mean sq. errror for XGboost  =", np.mean(pred_test-y_test)**2)
print(r2_score(y_test, pred_test))
y_testa=y_test.flatten()
preda=pred_test.flatten()
plt.scatter(y_testa,preda)
plt.xlabel('Actual values')
plt.ylabel('Predicted values')

plt.plot(np.unique(y_testa), np.poly1d(np.polyfit(y_testa, preda, 1))(np.unique(y_testa)),c='r',linewidth = '2')

plt.text(0.1, 0.8, 'R\u00b2 = %0.2f' % r2_score(y_testa, preda))
plt.show()
#plt.savefig('DTS1_plots/XGboost.png')
# Out:
# Mean sq. errror for ANN  = 3.056159770473148e-06
# 0.9609011780908852
# Mean sq. errror for Decision-Tree-Regression  = 1.2145963864929717e-07
# 0.9488362728874495
# Mean sq. errror for randomforest  = 1.0627590470968432e-07
# 0.9713674210221319
# Mean sq. errror for SVM_rbf  = 7.358703190676728e-05
# 0.9397337162578808
# Mean sq. errror for XGboost  = 1.8397364768660823e-08
# 0.9749421564491209
